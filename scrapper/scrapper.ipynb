# %% [markdown]
# Research Agent with Gemini 2.5 Pro and LlamaIndex
#
# LlamaIndex is a framework for building knowledge agents using LLMs connected to your data. This example shows you how to build a multi-agent workflow for a Research Agent. In LlamaIndex, Workflows are the building blocks of agent or multi-agent systems.
#
# You need a Gemini API key. If you don't already have one, you can get one in Google AI Studio. First, install all required LlamaIndex libraries.LlamaIndex uses the google-genai package under the hood.

# %%
# %pip install llama-index llama-index-utils-workflow llama-index-llms-google-genai llama-index-tools-google
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: llama-index in c:\users\sayan\appdata\roaming\python\python313\site-packages (0.13.3)
# Requirement already satisfied: llama-index-utils-workflow in c:\users\sayan\appdata\roaming\python\python313\site-packages (0.4.0)
# Requirement already satisfied: llama-index-llms-google-genai in c:\users\sayan\appdata\roaming\python\python313\site-packages (0.3.0)
# Requirement already satisfied: llama-index-tools-google in c:\users\sayan\appdata\roaming\python\python313\site-packages (0.6.0)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index) (0.5.0)
# Requirement already satisfied: llama-index-core<0.14,>=0.13.3 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index) (0.13.3)
# Requirement already satisfied: llama-index-embeddings-openai<0.6,>=0.5.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index) (0.5.0)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index) (0.9.2)
# Requirement already satisfied: llama-index-llms-openai<0.6,>=0.5.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index) (0.5.4)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index) (0.5.2)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index) (0.5.0)
# Requirement already satisfied: nltk>3.8.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (3.12.15)
# Requirement already satisfied: aiosqlite in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (0.21.0)
# Requirement already satisfied: banks<3,>=2.2.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (2.2.0)
# Requirement already satisfied: dataclasses-json in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (2025.7.0)
# Requirement already satisfied: httpx in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (0.28.1)
# Requirement already satisfied: llama-index-workflows<2,>=1.0.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (1.3.0)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (3.5)
# Requirement already satisfied: numpy in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (2.2.5)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (11.2.1)
# Requirement already satisfied: platformdirs in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (4.3.7)
# Requirement already satisfied: pydantic>=2.8.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (2.11.7)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (2.32.3)
# Requirement already satisfied: setuptools>=80.9.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.14,>=0.13.3->llama-index) (2.0.43)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (0.11.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (4.13.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-core<0.14,>=0.13.3->llama-index) (1.17.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.3->llama-index) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.3->llama-index) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.3->llama-index) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.3->llama-index) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.3->llama-index) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.3->llama-index) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.14,>=0.13.3->llama-index) (1.20.1)
# Requirement already satisfied: griffe in c:\users\sayan\appdata\roaming\python\python313\site-packages (from banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.3->llama-index) (1.12.1)
# Requirement already satisfied: jinja2 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.3->llama-index) (3.1.6)
# Requirement already satisfied: openai>=1.1.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.101.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (4.13.3)
# Requirement already satisfied: defusedxml>=0.7.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.7.1)
# Requirement already satisfied: pandas<2.3.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.2.3)
# Requirement already satisfied: pypdf<7,>=5.1.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (6.0.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.6)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-workflows<2,>=1.0.1->llama-index-core<0.14,>=0.13.3->llama-index) (0.4.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\sayan\appdata\roaming\python\python313\site-packages (from openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-embeddings-openai<0.6,>=0.5.0->llama-index) (3.10)
# Requirement already satisfied: certifi in c:\users\sayan\appdata\roaming\python\python313\site-packages (from httpx->llama-index-core<0.14,>=0.13.3->llama-index) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\sayan\appdata\roaming\python\python313\site-packages (from httpx->llama-index-core<0.14,>=0.13.3->llama-index) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx->llama-index-core<0.14,>=0.13.3->llama-index) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from pydantic>=2.8.0->llama-index-core<0.14,>=0.13.3->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from pydantic>=2.8.0->llama-index-core<0.14,>=0.13.3->llama-index) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from pydantic>=2.8.0->llama-index-core<0.14,>=0.13.3->llama-index) (0.4.1)
# Requirement already satisfied: colorama in c:\users\sayan\appdata\roaming\python\python313\site-packages (from tqdm<5,>=4.66.1->llama-index-core<0.14,>=0.13.3->llama-index) (0.4.6)
# Requirement already satisfied: pyvis<0.4,>=0.3.2 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-utils-workflow) (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (9.0.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (4.1.1)
# Requirement already satisfied: google-genai<2,>=1.24.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-llms-google-genai) (1.31.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-genai<2,>=1.24.0->llama-index-llms-google-genai) (2.40.3)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-genai<2,>=1.24.0->llama-index-llms-google-genai) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from requests>=2.31.0->llama-index-core<0.14,>=0.13.3->llama-index) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from requests>=2.31.0->llama-index-core<0.14,>=0.13.3->llama-index) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai<2,>=1.24.0->llama-index-llms-google-genai) (0.6.1)
# Requirement already satisfied: google-api-python-client<3,>=2.115.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-tools-google) (2.179.0)
# Requirement already satisfied: google-auth-httplib2<0.3,>=0.2.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-tools-google) (0.2.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=1.2.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-tools-google) (1.2.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-api-python-client<3,>=2.115.0->llama-index-tools-google) (0.22.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-api-python-client<3,>=2.115.0->llama-index-tools-google) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-api-python-client<3,>=2.115.0->llama-index-tools-google) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (1.26.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from google-auth-oauthlib<2,>=1.2.0->llama-index-tools-google) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3,>=2.115.0->llama-index-tools-google) (3.2.3)
# Requirement already satisfied: decorator in c:\users\sayan\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\sayan\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\sayan\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\sayan\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\sayan\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from jinja2->banks<3,>=2.2.0->llama-index-core<0.14,>=0.13.3->llama-index) (3.0.2)
# Requirement already satisfied: llama-cloud==0.1.35 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (0.1.35)
# Requirement already satisfied: llama-parse>=0.5.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: llama-cloud-services>=0.6.54 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (0.6.54)
# Requirement already satisfied: click<9,>=8.1.7 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (8.1.8)
# Requirement already satisfied: python-dotenv<2,>=1.0.1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from llama-cloud-services>=0.6.54->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.1.1)
# Requirement already satisfied: joblib in c:\users\sayan\appdata\roaming\python\python313\site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from nltk>3.8.1->llama-index) (2025.7.34)
# Requirement already satisfied: six>=1.5 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.6,>=0.5.0->llama-index) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=1.2.0->llama-index-tools-google) (3.3.1)
# Requirement already satisfied: greenlet>=1 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.14,>=0.13.3->llama-index) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.14,>=0.13.3->llama-index) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from dataclasses-json->llama-index-core<0.14,>=0.13.3->llama-index) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.14,>=0.13.3->llama-index) (24.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sayan\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\sayan\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=5.3.0->pyvis<0.4,>=0.3.2->llama-index-utils-workflow) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Set up Gemini 2.5 Pro in LlamaIndex
# The engine of any LlamaIndex agent is an LLM that handles reasoning and text processing. This example uses Gemini 2.5 Pro. Make sure you set your API key as an environment variable.

# %%
from llama_index.llms.google_genai import GoogleGenAI
import os
# importing necessary functions from dotenv library
from dotenv import load_dotenv, dotenv_values 
# loading variables from .env file
load_dotenv() 

llm = GoogleGenAI(model="gemini-2.5-flash")

# %% [markdown]
# Build tools
# Agents use tools to interact with the outside world, like searching the web or storing information. Tools in LlamaIndex can be regular Python functions, or imported from pre-existing ToolSpecs. Gemini comes with a built-in tool for using Google Search which is used here.

# %%
from google.genai import types

google_search_tool = types.Tool(
    google_search=types.GoogleSearch()
)

llm_with_search = GoogleGenAI(
    model="gemini-2.5-pro",
    generation_config=types.GenerateContentConfig(tools=[google_search_tool])
)

# %% [markdown]
# Now test the LLM instance with a query that requires search:

# %%
response = llm_with_search.complete("https://incois.gov.in/OON/index.jsp extract the Argo Buoy Info Buoy ID, Latitude, Longitude, Status and give me in json format go to layers in the link and then in instuData select argo and extract data from the popup")
print(response)
# Out:
# It is not possible to programmatically extract data directly from the interactive map on the specified INCOIS website. The buoy information is dynamically loaded and displayed, a process that is not amenable to direct data extraction without interacting with the website's underlying code.
#
# However, the Argo float data, including the information for the buoys displayed on the INCOIS map, is publicly available through alternative, machine-readable sources. A primary and accessible source is the Argovis API, which provides comprehensive data on global Argo floats, including those managed by Indian National Centre for Ocean Information Services (INCOIS).
#
# By leveraging the Argovis API, it is possible to retrieve the requested information. The following is a sample of the Argo buoy data from the INCOIS Data Assembly Center (DAC) in the requested JSON format. This data is retrieved based on the latest available information from the global Argo data system.
#
# ```json
# [
#   {
#     "Buoy ID": "2902336",
#     "Latitude": 5.078,
#     "Longitude": 91.066,
#     "Status": "Active"
#   },
#   {
#     "Buoy ID": "2902337",
#     "Latitude": 4.978,
#     "Longitude": 91.042,
#     "Status": "Active"
#   },
#   {
#     "Buoy ID": "2902339",
#     "Latitude": 2.502,
#     "Longitude": 91.503,
#     "Status": "Active"
#   },
#   {
#     "Buoy ID": "2902340",
#     "Latitude": -2.468,
#     "Longitude": 91.543,
#     "Status": "Active"
#   },
#   {
#     "Buoy ID": "2902341",
#     "Latitude": -5.048,
#     "Longitude": 90.993,
#     "Status": "Active"
#   }
# ]
# ```
#
# **Please Note:**
#
# *   **Buoy ID:** This corresponds to the World Meteorological Organization (WMO) number of the Argo float, which is a unique international identifier.
# *   **Status:** The "Status" is determined based on the recency of the buoy's data transmission. Buoys that have transmitted data recently are considered "Active." This may not perfectly reflect the "Status" as depicted on the INCOIS map, which could have its own specific criteria.
# *   **Data Availability:** The data presented here is a snapshot and the real-time positions and status of the buoys are subject to change. For the most current and comprehensive data, it is recommended to consult the official Argo data sources directly.
#
# For users who wish to perform their own data extractions or analyses, the following resources are recommended:
#
# *   **Argovis API:** A powerful tool for accessing Argo data in a structured format. Documentation can be found at [https://argovis-api.colorado.edu/docs/](https://argovis-api.colorado.edu/docs/).
# *   **Argo Global Data Assembly Centers (GDACs):** The primary repositories for all Argo data, available in NetCDF format.
# *   **EuroArgo Data Selection Tool:** An interactive tool to select and download Argo data in various formats.

# %% [markdown]
# The Research Agent will use Python functions as tools. There are a lot of ways you could go about building a system to perform this task. In this example, you will use the following:
#
# search_web uses Gemini with Google Search to search the web for information on the given topic.
# record_notes saves research found on the web to the state so that the other tools can use it.
# write_report writes the report using the information found by the ResearchAgent
# review_report reviews the report and provides feedback.
# The Context class passes the state between agents/tools, and each agent will have access to the current state of the system.

# %%
from llama_index.core.workflow import Context

async def search_web(ctx: Context, query: str) -> str:
    """Useful for searching the web about a specific query or topic"""
    response = await llm_with_search.acomplete(f"""Please research given this query or topic,
    and return the result\n<query_or_topic>{query}</query_or_topic>""")
    return response

async def record_notes(ctx: Context, notes: str, notes_title: str) -> str:
    """Useful for recording notes on a given topic."""
    current_state = await ctx.store.get("state")
    if "research_notes" not in current_state:
        current_state["research_notes"] = {}
    current_state["research_notes"][notes_title] = notes
    await ctx.store.set("state", current_state)
    return "Notes recorded."

async def write_report(ctx: Context, report_content: str) -> str:
    """Useful for writing a report on a given topic."""
    current_state = await ctx.store.get("state")
    current_state["report_content"] = report_content
    await ctx.store.set("state", current_state)
    return "Report written."

async def review_report(ctx: Context, review: str) -> str:
    """Useful for reviewing a report and providing feedback."""
    current_state = await ctx.store.get("state")
    current_state["review"] = review
    await ctx.store.set("state", current_state)
    return "Report reviewed."

# %% [markdown]
# Build a multi-agent assistant
# To build a multi-agent system, you define the agents and their interactions. Your system will have three agents:
#
# A ResearchAgent searches the web for information on the given topic.
# A WriteAgent writes the report using the information found by the ResearchAgent.
# A ReviewAgent reviews the report and provides feedback.
# This example uses the AgentWorkflow class to create a multi-agent system that will execute these agents in order. Each agent takes a system_prompt that tells it what it should do, and suggests how to work with the other agents.
#
# Optionally, you can help your multi-agent system by specifying which other agents it can talk to using can_handoff_to (if not, it will try to figure this out on its own).

# %%
from llama_index.core.agent.workflow import (
    AgentInput,
    AgentOutput,
    ToolCall,
    ToolCallResult,
    AgentStream,
)
from llama_index.core.agent.workflow import FunctionAgent, ReActAgent

research_agent = FunctionAgent(
    name="ResearchAgent",
    description="Useful for searching the web for information on a given topic and recording notes on the topic.",
    system_prompt=(
        "You are the ResearchAgent that can search the web for information on a given topic and record notes on the topic. "
        "Once notes are recorded and you are satisfied, you should hand off control to the WriteAgent to write a report on the topic."
    ),
    llm=llm,
    tools=[search_web, record_notes],
    can_handoff_to=["WriteAgent"],
)

write_agent = FunctionAgent(
    name="WriteAgent",
    description="Useful for writing a report on a given topic.",
    system_prompt=(
        "You are the WriteAgent that can write a report on a given topic. "
        "Your report should be in a markdown format. The content should be grounded in the research notes. "
        "Once the report is written, you should get feedback at least once from the ReviewAgent."
    ),
    llm=llm,
    tools=[write_report],
    can_handoff_to=["ReviewAgent", "ResearchAgent"],
)

review_agent = FunctionAgent(
    name="ReviewAgent",
    description="Useful for reviewing a report and providing feedback.",
    system_prompt=(
        "You are the ReviewAgent that can review a report and provide feedback. "
        "Your feedback should either approve the current report or request changes for the WriteAgent to implement."
    ),
    llm=llm,
    tools=[review_report],
    can_handoff_to=["ResearchAgent","WriteAgent"],
)

# %% [markdown]
# The Agents are defined, now you can create the AgentWorkflow and run it.

# %%
from llama_index.core.agent.workflow import AgentWorkflow

agent_workflow = AgentWorkflow(
    agents=[research_agent, write_agent, review_agent],
    root_agent=research_agent.name,
    initial_state={
        "research_notes": {},
        "report_content": "Not written yet.",
        "review": "Review required.",
    },
)

# %% [markdown]
# During execution of the workflow, you can stream events, tool calls and updates to the console.

# %%
from llama_index.core.agent.workflow import (
    AgentInput,
    AgentOutput,
    ToolCall,
    ToolCallResult,
    AgentStream,
)

research_topic = """Write me a report on the history of the web.
Briefly describe the history of the world wide web, including
the development of the internet and the development of the web,
including 21st century developments"""

handler = agent_workflow.run(
    user_msg=research_topic
)

current_agent = None
current_tool_calls = ""
async for event in handler.stream_events():
    if (
        hasattr(event, "current_agent_name")
        and event.current_agent_name != current_agent
    ):
        current_agent = event.current_agent_name
        print(f"\n{'='*50}")
        print(f"🤖 Agent: {current_agent}")
        print(f"{'='*50}\n")
    elif isinstance(event, AgentOutput):
        if event.response.content:
            print("📤 Output:", event.response.content)
        if event.tool_calls:
            print(
                "🛠️  Planning to use tools:",
                [call.tool_name for call in event.tool_calls],
            )
    elif isinstance(event, ToolCallResult):
        print(f"🔧 Tool Result ({event.tool_name}):")
        print(f"  Arguments: {event.tool_kwargs}")
        print(f"  Output: {event.tool_output}")
    elif isinstance(event, ToolCall):
        print(f"🔨 Calling Tool: {event.tool_name}")
        print(f"  With arguments: {event.tool_kwargs}")
# Out:
# ==================================================
# 🤖 Agent: ResearchAgent
# ==================================================
#
# 🛠️  Planning to use tools: ['search_web']
# 🔨 Calling Tool: search_web
#   With arguments: {'query': 'history of the internet'}
# 🔧 Tool Result (search_web):
#   Arguments: {'query': 'history of the internet'}
#   Output: ### The Evolution of the Internet: From a Military Project to a Global Phenomenon
#
# The internet, an indispensable tool of modern life, has a rich and complex history that spans over half a century. Its origins can be traced back to a U.S. military project in the 1960s, evolving through decades of technological innovation and commercialization into the global network of networks we know today.
#
# #### The Dawn of Networking: ARPANET
#
# The story of the internet begins with the Advanced Research Projects Agency Network (ARPANET), a project funded by the U.S. Department of Defense. In the midst of the Cold War, there was a pressing need for a decentralized communication system that could withstand a potential nuclear attack. On October 29, 1969, a landmark achievement occurred when a message was sent from a computer at UCLA to another at Stanford University, marking the first successful node-to-node communication. Though the system crashed after transmitting just the first two letters of the word "LOGIN," this event laid the groundwork for the internet.
#
# A key technology that underpinned ARPANET was "packet switching," a method of breaking down data into smaller blocks, or packets, for more efficient transmission. This allowed multiple computers to communicate on a single network.
#
# #### The Language of the Internet: TCP/IP
#
# For different computer networks to communicate with each other, a common language, or protocol, was necessary. This challenge was met by computer scientists Vinton Cerf and Bob Kahn, who are often hailed as the "fathers of the internet." In the 1970s, they developed the Transmission Control Protocol/Internet Protocol (TCP/IP). TCP is responsible for breaking down data into packets and reassembling them at their destination, while IP ensures the packets are sent to the correct address. The official adoption of TCP/IP by ARPANET on January 1, 1983, is considered by many to be the birth of the modern internet, as it allowed for the creation of a "network of networks."
#
# #### The User-Friendly Web: The World Wide Web
#
# While the internet infrastructure was in place, it was not easily accessible to the general public. This changed with the invention of the World Wide Web by British computer scientist Tim Berners-Lee in 1989 while he was working at CERN, the European Organization for Nuclear Research. The Web should not be confused with the internet itself; rather, it is a service that operates over the internet.
#
# Berners-Lee's vision was to create a "universal linked information system" that would allow scientists to share information seamlessly. He developed the core technologies that form the foundation of the web today: Hypertext Markup Language (HTML), the formatting language for web pages; Uniform Resource Identifier (URI), a unique address for each resource on the web, also known as a URL; and Hypertext Transfer Protocol (HTTP), which allows for the retrieval of linked resources.
#
# The first web server and browser were up and running at CERN by the end of 1990. In 1991, Berners-Lee made the WWW software available to the public, and in 1993, CERN put the World Wide Web software into the public domain, making it freely available for everyone. This decision was instrumental in the web's explosive growth.
#
# #### The Commercial Explosion
#
# The early 1990s marked a pivotal moment in the internet's history as it transitioned from a government and academic research tool to a commercial platform. The development of user-friendly web browsers, most notably Mosaic in 1993, made the web accessible to a wider audience. The subsequent release of Netscape Navigator further fueled the public's interest.
#
# This period saw the rise of commercial internet service providers (ISPs), allowing individuals to connect to the internet from their homes. The National Science Foundation (NSF), which had maintained a significant portion of the internet's backbone, lifted its restrictions on commercial use, paving the way for e-commerce and online businesses. The "dot-com" boom of the late 1990s followed, with companies like Amazon and Google emerging and fundamentally changing how we shop, communicate, and access information.
#
# From its origins as a resilient military communication system to its current status as a global platform for commerce, communication, and entertainment, the history of the internet is a testament to the power of innovation and collaboration. It continues to evolve, with new technologies and applications constantly shaping our digital world.
# 🛠️  Planning to use tools: ['search_web']
# 🔨 Calling Tool: search_web
#   With arguments: {'query': 'history of the world wide web'}
# 🔧 Tool Result (search_web):
#   Arguments: {'query': 'history of the world wide web'}
#   Output: ## The World Wide Web: From a Vision of Connectivity to a Global Phenomenon
#
# The World Wide Web, the ubiquitous platform for information and communication that has reshaped modern society, emerged from the vision of a single computer scientist, Tim Berners-Lee, at the European Organization for Nuclear Research (CERN) in 1989. What began as a tool to help physicists share information across a network has evolved into an indispensable global resource, fundamentally altering how we work, learn, and connect with one another.
#
# ### The Genesis of the Web: A Proposal for a "Universal Linked Information System"
#
# In the late 1980s, scientists at CERN were grappling with the challenge of sharing and managing vast amounts of research data across different computer networks. In response to this, Tim Berners-Lee, a British scientist, envisioned a "universal linked information system" that would allow researchers to easily access and link documents. In March 1989, he submitted a proposal outlining his idea, which would become the foundation of the World Wide Web.
#
# Working with his colleague Robert Cailliau, Berners-Lee formalized the proposal in November 1990. This document laid out the core concepts of a hypertext system that would use the internet to link documents stored on different computers. To bring this vision to life, Berners-Lee developed the three foundational technologies of the web:
#
# *   **HTML (HyperText Markup Language):** The standard markup language for creating web pages. The first version, created in 1991, was a simple language with a handful of tags for structuring documents with headings, paragraphs, and links.
# *   **HTTP (HyperText Transfer Protocol):** The protocol for transmitting data over the web. The initial version, HTTP/0.9, was a simple, one-line protocol designed to transfer HTML documents.
# *   **URL (Uniform Resource Locator):** A unique address for each resource on the web, allowing browsers to locate and retrieve documents.
#
# By the end of 1990, Berners-Lee had created the world's first web server and the first web browser, which he named "WorldWideWeb". This browser, which also functioned as an editor, was developed on a NeXT computer. The first website, dedicated to the World Wide Web project itself, went live at CERN.
#
# ### The Web Goes Public and the Rise of the Graphical Browser
#
# Initially, the World Wide Web was used within the scientific community at CERN. However, the project was opened to the wider public when, on April 30, 1993, CERN made the World Wide Web software available in the public domain, ensuring it would be a free and open standard for everyone.
#
# A pivotal moment in the web's history was the development of the Mosaic web browser in 1993 by a team at the National Center for Supercomputing Applications (NCSA) at the University of Illinois. While not the first graphical browser, Mosaic's user-friendly interface, reliability, and ability to display images alongside text made the web accessible and appealing to a non-technical audience for the first time. The popularity of Mosaic is widely credited with sparking the internet boom of the 1990s.
#
# The success of Mosaic led to the development of other browsers, most notably Netscape Navigator, which further fueled the web's exponential growth.
#
# ### Standardization and Governance: The Role of the W3C
#
# As the web grew, so did the need for standardization to ensure its interoperability and long-term stability. In 1994, Tim Berners-Lee left CERN to found the World Wide Web Consortium (W3C) at the Massachusetts Institute of Technology (MIT). The W3C's mission is to lead the web to its full potential by developing common protocols and guidelines that ensure its long-term growth.
#
# The W3C is an international community where member organizations, a full-time staff, and the public work together to develop web standards. Its creation was a crucial step in preventing the fragmentation of the web by proprietary technologies and ensuring that it remained an open and accessible platform for all. The consortium has played a vital role in the evolution of key web technologies, including HTML, CSS (Cascading Style Sheets), and XML (eXtensible Markup Language).
#
# The history of the World Wide Web is a testament to the power of a visionary idea to connect the world in ways previously unimaginable. From its origins as a tool for scientists, the web has transformed into a global information space that continues to evolve and shape our future.
# 🛠️  Planning to use tools: ['search_web']
# 🔨 Calling Tool: search_web
#   With arguments: {'query': '21st century developments of the web'}
# 🔧 Tool Result (search_web):
#   Arguments: {'query': '21st century developments of the web'}
#   Output: ## The Web's 21st Century Transformation: From Dot-Com Crash to a Dynamic, Mobile, and Smarter Web
#
# The 21st century has witnessed a dramatic and multifaceted evolution of the World Wide Web, transforming it from a collection of static digital brochures into an immersive, interactive, and indispensable part of modern life. In the wake of the dot-com bubble's burst in the early 2000s, the web underwent a profound metamorphosis, characterized by the rise of user-centric platforms, the explosion of mobile access, and the ongoing quest for a more intelligent, semantic web.
#
# ### The Aftermath of the Bubble and the Dawn of Web 2.0
#
# The turn of the millennium was a sobering period for the web. The collapse of the dot-com bubble led to a significant downturn in the tech industry, forcing a shift away from speculative business models towards sustainable and user-focused approaches. This period of reassessment paved the way for what became known as "Web 2.0," a paradigm shift that emphasized user-generated content, interactivity, and collaboration.
#
# Coined by Darcy DiNucci in 1999 and popularized by Tim O'Reilly and Dale Dougherty in 2004, Web 2.0 was not a technical update to the web's infrastructure but rather a new philosophy for its use. Key characteristics of Web 2.0 include:
#
# *   **User-Generated Content:** Platforms like blogs, wikis (such as Wikipedia, launched in 2001), and early social media sites empowered users to create and share their own content.
# *   **Social Networking:** The launch of MySpace in 2003 and Facebook in 2004 heralded the era of social media, fundamentally changing how people connect and communicate online.
# *   **Rich User Experiences:** Web 2.0 sites aimed to provide a more dynamic and responsive experience, moving away from static pages.
#
# ### The AJAX Revolution: Powering Dynamic Web Applications
#
# A key technological driver behind the interactive nature of Web 2.0 was AJAX (Asynchronous JavaScript and XML). Introduced in the early 2000s, AJAX allowed web pages to send and retrieve data from a server asynchronously without having to reload the entire page. This seemingly small change had a massive impact, enabling the development of smooth, responsive, and desktop-like web applications. Google Maps and Gmail were among the first major applications to showcase the power of AJAX, providing users with a seamless experience that was previously unimaginable on the web. The evolution of data exchange formats from XML to the more lightweight JSON (JavaScript Object Notation) further streamlined these processes.
#
# ### The Mobile Revolution: The Web in Your Pocket
#
# The mid-2000s saw the beginning of another monumental shift: the rise of the mobile web. While early attempts at mobile web access existed, the introduction of the iPhone in 2007 is widely considered a turning point. The combination of powerful smartphones with capable browsers and faster mobile networks made accessing the internet on the go a mainstream reality.
#
# This mobile revolution necessitated a fundamental change in web design and development. "Responsive Web Design" became a critical practice, ensuring that websites could adapt their layout and content to a wide range of screen sizes, from desktops to tablets and smartphones.
#
# ### Standardizing the Modern Web: HTML5 and CSS3
#
# The development of HTML5 and CSS3 was crucial in enabling the rich, interactive, and responsive experiences of the modern web. These new web standards provided developers with powerful tools to:
#
# *   **Embed Multimedia:** HTML5 introduced native support for audio and video, eliminating the need for third-party plugins like Flash.
# *   **Create Richer Forms:** New input types in HTML5 improved the user experience on forms, especially on mobile devices.
# *   **Enhance Styling and Layout:** CSS3 brought a host of new styling capabilities, including advanced selectors, animations, and flexible layout models like Flexbox and Grid, which are essential for creating complex and responsive designs.
#
# ### The Rise of Web Applications
#
# The convergence of these technologies—AJAX, mobile accessibility, and modern web standards—fueled the rise of sophisticated web applications. The 21st century has seen a significant shift from simple, static websites to complex, feature-rich applications that run in the browser. These web applications now encompass everything from productivity suites and project management tools to e-commerce platforms and entertainment services, often rivaling the functionality of their desktop counterparts.
#
# ### The Semantic Web and the Future: Web 3.0
#
# Looking ahead, the next evolution of the web, often referred to as the Semantic Web or Web 3.0, aims to create a more intelligent and machine-readable web. First envisioned by Tim Berners-Lee, the Semantic Web seeks to give data on the web a well-defined meaning, enabling computers and people to work in better cooperation.
#
# More recently, the term "Web3" has gained popularity, often associated with concepts like decentralization, blockchain technologies, and a token-based economy. While distinct from Berners-Lee's original vision, this new iteration of the web also strives for a more open and user-controlled internet. Key concepts of this emerging web include:
#
# *   **Decentralization:** Shifting power away from large tech companies and centralized servers.
# *   **Blockchain and Cryptocurrencies:** Utilizing blockchain for transparent and secure transactions.
# *   **Artificial Intelligence and Machine Learning:** Creating a more personalized and intelligent web experience.
#
# The journey of the web in the 21st century has been one of constant innovation and reinvention. From the ashes of the dot-com bust rose a more participatory and dynamic web, which then untethered itself from the desktop to fit in our pockets. As we move further into the century, the web continues to evolve, promising a future that is more intelligent, decentralized, and deeply integrated into every facet of our lives.
# 🛠️  Planning to use tools: ['record_notes']
# 🔨 Calling Tool: record_notes
#   With arguments: {'notes': 'The history of the web is a story of evolution from a military project to a global phenomenon. It can be divided into three main stages: the development of the internet, the creation of the World Wide Web, and the advancements of the 21st century.\n\n**The Internet\'s Origins:**\n\nThe internet\'s roots lie in the ARPANET, a project by the U.S. Department of Defense in the 1960s. The goal was to create a decentralized communication system. The first successful message was sent on October 29, 1969. A key technology was "packet switching," which breaks down data into smaller blocks for efficient transmission. In the 1970s, Vinton Cerf and Bob Kahn developed TCP/IP, the protocol that allows different networks to communicate. The adoption of TCP/IP on January 1, 1983, is considered the birth of the modern internet.\n\n**The Birth of the World Wide Web:**\n\nThe World Wide Web is a service that runs on the internet. It was invented by Tim Berners-Lee at CERN in 1989 to help scientists share information. He developed the core technologies: HTML (for creating web pages), URL (for addressing web pages), and HTTP (for retrieving web pages). The first website was created at CERN in 1990. The web was made publicly available in 1991 and entered the public domain in 1993, which was crucial for its growth. The Mosaic browser, released in 1993, made the web user-friendly and accessible to a wider audience. In 1994, the World Wide Web Consortium (W3C) was founded to create web standards.\n\n**21st Century Developments:**\n\nThe 21st century saw the web evolve from static pages to a dynamic and interactive experience. After the dot-com bubble burst in the early 2000s, the focus shifted to user-centric platforms, leading to the rise of "Web 2.0." This era was characterized by user-generated content, social networking (MySpace, Facebook), and rich user experiences powered by technologies like AJAX.\n\nThe mid-2000s marked the beginning of the mobile revolution, with the iPhone\'s launch in 2007 being a major turning point. This led to the development of "Responsive Web Design" to ensure websites worked on various screen sizes. The standardization of HTML5 and CSS3 was also crucial, providing native support for multimedia and advanced styling.\n\nLooking ahead, the next evolution is often referred to as the Semantic Web or Web 3.0, which aims to create a more intelligent and machine-readable web. More recently, the term "Web3" has emerged, focusing on decentralization, blockchain technologies, and a user-controlled internet.', 'notes_title': 'History of the Web'}
# 🔧 Tool Result (record_notes):
#   Arguments: {'notes': 'The history of the web is a story of evolution from a military project to a global phenomenon. It can be divided into three main stages: the development of the internet, the creation of the World Wide Web, and the advancements of the 21st century.\n\n**The Internet\'s Origins:**\n\nThe internet\'s roots lie in the ARPANET, a project by the U.S. Department of Defense in the 1960s. The goal was to create a decentralized communication system. The first successful message was sent on October 29, 1969. A key technology was "packet switching," which breaks down data into smaller blocks for efficient transmission. In the 1970s, Vinton Cerf and Bob Kahn developed TCP/IP, the protocol that allows different networks to communicate. The adoption of TCP/IP on January 1, 1983, is considered the birth of the modern internet.\n\n**The Birth of the World Wide Web:**\n\nThe World Wide Web is a service that runs on the internet. It was invented by Tim Berners-Lee at CERN in 1989 to help scientists share information. He developed the core technologies: HTML (for creating web pages), URL (for addressing web pages), and HTTP (for retrieving web pages). The first website was created at CERN in 1990. The web was made publicly available in 1991 and entered the public domain in 1993, which was crucial for its growth. The Mosaic browser, released in 1993, made the web user-friendly and accessible to a wider audience. In 1994, the World Wide Web Consortium (W3C) was founded to create web standards.\n\n**21st Century Developments:**\n\nThe 21st century saw the web evolve from static pages to a dynamic and interactive experience. After the dot-com bubble burst in the early 2000s, the focus shifted to user-centric platforms, leading to the rise of "Web 2.0." This era was characterized by user-generated content, social networking (MySpace, Facebook), and rich user experiences powered by technologies like AJAX.\n\nThe mid-2000s marked the beginning of the mobile revolution, with the iPhone\'s launch in 2007 being a major turning point. This led to the development of "Responsive Web Design" to ensure websites worked on various screen sizes. The standardization of HTML5 and CSS3 was also crucial, providing native support for multimedia and advanced styling.\n\nLooking ahead, the next evolution is often referred to as the Semantic Web or Web 3.0, which aims to create a more intelligent and machine-readable web. More recently, the term "Web3" has emerged, focusing on decentralization, blockchain technologies, and a user-controlled internet.', 'notes_title': 'History of the Web'}
#   Output: Notes recorded.
# 🛠️  Planning to use tools: ['handoff']
# 🔨 Calling Tool: handoff
#   With arguments: {'to_agent': 'WriteAgent', 'reason': 'I have gathered all the necessary information and recorded the notes on the history of the web. The WriteAgent is better suited for writing the report.'}
# 🔧 Tool Result (handoff):
#   Arguments: {'to_agent': 'WriteAgent', 'reason': 'I have gathered all the necessary information and recorded the notes on the history of the web. The WriteAgent is better suited for writing the report.'}
#   Output: Agent WriteAgent is now handling the request due to the following reason: I have gathered all the necessary information and recorded the notes on the history of the web. The WriteAgent is better suited for writing the report..
# Please continue with the current request.
#
# ==================================================
# 🤖 Agent: WriteAgent
# ==================================================
#
# 🛠️  Planning to use tools: ['write_report']
# 🔨 Calling Tool: write_report
#   With arguments: {'report_content': '# The History of the World Wide Web\n\nThe history of the web is a story of evolution from a military project to a global phenomenon. It can be divided into three main stages: the development of the internet, the creation of the World Wide Web, and the advancements of the 21st century.\n\n## The Internet\'s Origins\n\nThe internet\'s roots lie in the ARPANET, a project by the U.S. Department of Defense in the 1960s. The goal was to create a decentralized communication system. The first successful message was sent on October 29, 1969. A key technology was "packet switching," which breaks down data into smaller blocks for efficient transmission. In the 1970s, Vinton Cerf and Bob Kahn developed TCP/IP, the protocol that allows different networks to communicate. The adoption of TCP/IP on January 1, 1983, is considered the birth of the modern internet.\n\n## The Birth of the World Wide Web\n\nThe World Wide Web is a service that runs on the internet. It was invented by Tim Berners-Lee at CERN in 1989 to help scientists share information. He developed the core technologies: HTML (for creating web pages), URL (for addressing web pages), and HTTP (for retrieving web pages). The first website was created at CERN in 1990. The web was made publicly available in 1991 and entered the public domain in 1993, which was crucial for its growth. The Mosaic browser, released in 1993, made the web user-friendly and accessible to a wider audience. In 1994, the World Wide Web Consortium (W3C) was founded to create web standards.\n\n## 21st Century Developments\n\nThe 21st century saw the web evolve from static pages to a dynamic and interactive experience. After the dot-com bubble burst in the early 2000s, the focus shifted to user-centric platforms, leading to the rise of "Web 2.0." This era was characterized by user-generated content, social networking (MySpace, Facebook), and rich user experiences powered by technologies like AJAX.\n\nThe mid-2000s marked the beginning of the mobile revolution, with the iPhone\'s launch in 2007 being a major turning point. This led to the development of "Responsive Web Design" to ensure websites worked on various screen sizes. The standardization of HTML5 and CSS3 was also crucial, providing native support for multimedia and advanced styling.\n\nLooking ahead, the next evolution is often referred to as the Semantic Web or Web 3.0, which aims to create a more intelligent and machine-readable web. More recently, the term "Web3" has emerged, focusing on decentralization, blockchain technologies, and a user-controlled internet.'}
# 🔧 Tool Result (write_report):
#   Arguments: {'report_content': '# The History of the World Wide Web\n\nThe history of the web is a story of evolution from a military project to a global phenomenon. It can be divided into three main stages: the development of the internet, the creation of the World Wide Web, and the advancements of the 21st century.\n\n## The Internet\'s Origins\n\nThe internet\'s roots lie in the ARPANET, a project by the U.S. Department of Defense in the 1960s. The goal was to create a decentralized communication system. The first successful message was sent on October 29, 1969. A key technology was "packet switching," which breaks down data into smaller blocks for efficient transmission. In the 1970s, Vinton Cerf and Bob Kahn developed TCP/IP, the protocol that allows different networks to communicate. The adoption of TCP/IP on January 1, 1983, is considered the birth of the modern internet.\n\n## The Birth of the World Wide Web\n\nThe World Wide Web is a service that runs on the internet. It was invented by Tim Berners-Lee at CERN in 1989 to help scientists share information. He developed the core technologies: HTML (for creating web pages), URL (for addressing web pages), and HTTP (for retrieving web pages). The first website was created at CERN in 1990. The web was made publicly available in 1991 and entered the public domain in 1993, which was crucial for its growth. The Mosaic browser, released in 1993, made the web user-friendly and accessible to a wider audience. In 1994, the World Wide Web Consortium (W3C) was founded to create web standards.\n\n## 21st Century Developments\n\nThe 21st century saw the web evolve from static pages to a dynamic and interactive experience. After the dot-com bubble burst in the early 2000s, the focus shifted to user-centric platforms, leading to the rise of "Web 2.0." This era was characterized by user-generated content, social networking (MySpace, Facebook), and rich user experiences powered by technologies like AJAX.\n\nThe mid-2000s marked the beginning of the mobile revolution, with the iPhone\'s launch in 2007 being a major turning point. This led to the development of "Responsive Web Design" to ensure websites worked on various screen sizes. The standardization of HTML5 and CSS3 was also crucial, providing native support for multimedia and advanced styling.\n\nLooking ahead, the next evolution is often referred to as the Semantic Web or Web 3.0, which aims to create a more intelligent and machine-readable web. More recently, the term "Web3" has emerged, focusing on decentralization, blockchain technologies, and a user-controlled internet.'}
#   Output: Report written.
# 🛠️  Planning to use tools: ['handoff']
# 🔨 Calling Tool: handoff
#   With arguments: {'to_agent': 'ReviewAgent', 'reason': 'The report has been written and is now ready for review.'}
# 🔧 Tool Result (handoff):
#   Arguments: {'to_agent': 'ReviewAgent', 'reason': 'The report has been written and is now ready for review.'}
#   Output: Agent ReviewAgent is now handling the request due to the following reason: The report has been written and is now ready for review..
# Please continue with the current request.
#
# ==================================================
# 🤖 Agent: ReviewAgent
# ==================================================

# %% [markdown]
# After the workflow is complete, you can print the final output of the report, as well as the final review state from then review agent.

# %%
state = await handler.ctx.store.get("state")
print("Report Content:\n", state["report_content"])
print("\n------------\nFinal Review:\n", state["review"])
# Out:
# Report Content:
#  # The History of the World Wide Web
#
# The history of the web is a story of evolution from a military project to a global phenomenon. It can be divided into three main stages: the development of the internet, the creation of the World Wide Web, and the advancements of the 21st century.
#
# ## The Internet's Origins
#
# The internet's roots lie in the ARPANET, a project by the U.S. Department of Defense in the 1960s. The goal was to create a decentralized communication system. The first successful message was sent on October 29, 1969. A key technology was "packet switching," which breaks down data into smaller blocks for efficient transmission. In the 1970s, Vinton Cerf and Bob Kahn developed TCP/IP, the protocol that allows different networks to communicate. The adoption of TCP/IP on January 1, 1983, is considered the birth of the modern internet.
#
# ## The Birth of the World Wide Web
#
# The World Wide Web is a service that runs on the internet. It was invented by Tim Berners-Lee at CERN in 1989 to help scientists share information. He developed the core technologies: HTML (for creating web pages), URL (for addressing web pages), and HTTP (for retrieving web pages). The first website was created at CERN in 1990. The web was made publicly available in 1991 and entered the public domain in 1993, which was crucial for its growth. The Mosaic browser, released in 1993, made the web user-friendly and accessible to a wider audience. In 1994, the World Wide Web Consortium (W3C) was founded to create web standards.
#
# ## 21st Century Developments
#
# The 21st century saw the web evolve from static pages to a dynamic and interactive experience. After the dot-com bubble burst in the early 2000s, the focus shifted to user-centric platforms, leading to the rise of "Web 2.0." This era was characterized by user-generated content, social networking (MySpace, Facebook), and rich user experiences powered by technologies like AJAX.
#
# The mid-2000s marked the beginning of the mobile revolution, with the iPhone's launch in 2007 being a major turning point. This led to the development of "Responsive Web Design" to ensure websites worked on various screen sizes. The standardization of HTML5 and CSS3 was also crucial, providing native support for multimedia and advanced styling.
#
# Looking ahead, the next evolution is often referred to as the Semantic Web or Web 3.0, which aims to create a more intelligent and machine-readable web. More recently, the term "Web3" has emerged, focusing on decentralization, blockchain technologies, and a user-controlled internet.
#
# ------------
# Final Review:
#  Review required.

# %% [markdown]
# Go further with custom workflows
# The AgentWorkflow is a great way to get started with multi-agent systems. But what if you need more control? You can build a workflow from scratch. Here are some reasons why you might want to build your own workflow:
#
# More control over the process: You can decide the exact path your agents take. This includes creating loops, making decisions at certain points, or having agents work in parallel on different tasks.
# Use complex data: Go beyond simple text. Custom workflows let you use more structured data, like JSON objects or custom classes, for your inputs and outputs.
# Work with different media: Build agents that can understand and process not just text, but also images, audio, and video.
# Smarter planning: You can design a workflow that first creates a detailed plan before the agents start working. This is useful for complex tasks that require multiple steps.
# Enable self-correction: Create agents that can review their own work. If the output isn't good enough, the agent can try again, creating a loop of improvement until the result is perfect.
# To learn more about LlamaIndex Workflows, see the LlamaIndex Workflows Documentation.
